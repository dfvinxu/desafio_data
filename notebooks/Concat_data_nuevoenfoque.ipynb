# %%
import pandas as pd

# %%
df_fuentes = pd.read_csv("../data/madrid/fuentes/fuentes_nuevo.csv")
df_museos = pd.read_csv("../data/madrid/museos/museos_nuevo.csv")
df_parques = pd.read_csv("../data/madrid/Parques y jardines/parques_y_jardines_nuevo.csv")
df_oficinas = pd.read_csv("../data/madrid/oficinas_turismo/tourist_office_nuevo.csv")
df_piscinas = pd.read_csv("../data/madrid/Piscinas/piscinas_madrid_nuevo.csv")

# %%
df_fuentes.head()
# Out:
#       TIPO       NOMBRE                     DIRECCION           DESCRIPCION  \
# 0  FUENTES  FUE_01_0001    CENTRO, PLAZA COMENDADORAS    PLAZA COMENDADORAS
# 1  FUENTES  FUE_01_0002  CENTRO, JARDINES CONDE DUQUE  JARDINES CONDE DUQUE
# 2  FUENTES  FUE_01_0003  CENTRO, PLAZA DE LAS SALESAS  PLAZA DE LAS SALESAS
# 3  FUENTES  FUE_01_0004  CENTRO, PLAZA VILLA DE PARIS  PLAZA VILLA DE PARIS
# 4  FUENTES  FUE_01_0005  CENTRO, PLAZA VILLA DE PARIS  PLAZA VILLA DE PARIS
#
#      LATITUD  LONGITUD
# 0  40.427243 -3.708600
# 1  40.428724 -3.710101
# 2  40.424246 -3.694603
# 3  40.425298 -3.692202
# 4  40.425562 -3.693176

# %%
df_museos.head()
# Out:
#      TIPO                                             NOMBRE  \
# 0  MUSEOS                            Casa Museo Lope de Vega
# 1  MUSEOS                     Casita - Museo del Ratón Pérez
# 2  MUSEOS                             Castillo de la Alameda
# 3  MUSEOS                             Casón del Buen Retiro.
# 4  MUSEOS  Centro Cultural La Corrala. Museo de Artes y T...
#
#                                 DIRECCION  \
# 0       CALLE CERVANTES 11, MADRID, 28014
# 1           CALLE ARENAL 8, MADRID, 28013
# 2   CALLE ANTONIO SANCHA 1, MADRID, 28042
# 3     CALLE ALFONSO XII 28, MADRID, 28014
# 4  CALLE CARLOS ARNICHES 3, MADRID, 28005
#
#                                          DESCRIPCION    LATITUD  LONGITUD
# 0  'Mi casilla, mi quietud, mi güertecillo y estu...  40.414358 -3.697474
# 1  La Casita-Museo de Ratón Pérez, constituye un ...  40.417060 -3.705520
# 2  El Castillo de la Alameda o de Barajas se trat...  40.458355 -3.593290
# 3  El Centro de Estudios del Prado está ubicado e...  40.415275 -3.689222
# 4                          Descripción no disponible  40.408827 -3.708324

# %%
df_parques.head()
# Out:
#                  TIPO                            NOMBRE  \
# 0  PARQUES_Y_JARDINES         Jardines Gregorio Ordóñez
# 1  PARQUES_Y_JARDINES  Jardines San Francisco el Grande
# 2  PARQUES_Y_JARDINES        Jardines de Andrés Saborit
# 3  PARQUES_Y_JARDINES        Jardines de El Buen Retiro
# 4  PARQUES_Y_JARDINES        Jardines de Gloria Fuertes
#
#                                            DIRECCION  \
# 0        CALLE PRINCIPE DE VERGARA 68, MADRID, 28006
# %%
df_concat = pd.concat([df_fuentes, df_museos, df_parques, df_oficinas, df_piscinas], ignore_index=True)
df_concat
# Out:
#           TIPO                                             NOMBRE  \
# 0      FUENTES                                        FUE_01_0001
# 1      FUENTES                                        FUE_01_0002
# 2      FUENTES                                        FUE_01_0003
# 3      FUENTES                                        FUE_01_0004
# 4      FUENTES                                        FUE_01_0005
# ...        ...                                                ...
# 2510  PISCINAS         Centro Deportivo Municipal Vallecas Verano
# 2511  PISCINAS            Centro Deportivo Municipal Vallehermoso
# 2512  PISCINAS      Centro Deportivo Municipal Vicente del Bosque
# 2513  PISCINAS  Centro Deportivo Municipal Wilfred Agbonavbare...
# 2514  PISCINAS                      Club de Campo Villa de Madrid
#
#                                               DIRECCION           DESCRIPCION  \
# 0                            CENTRO, PLAZA COMENDADORAS    PLAZA COMENDADORAS
# 1                          CENTRO, JARDINES CONDE DUQUE  JARDINES CONDE DUQUE
# 2                          CENTRO, PLAZA DE LAS SALESAS  PLAZA DE LAS SALESAS
# 3                          CENTRO, PLAZA VILLA DE PARIS  PLAZA VILLA DE PARIS
# 4                          CENTRO, PLAZA VILLA DE PARIS  PLAZA VILLA DE PARIS
# ...                                                 ...                   ...
# 2510        CALLE ARROYO DEL OLIVAR 51.0, MADRID, 28018         No disponible
# 2511               AVENIDA FILIPINAS 7.0, MADRID, 28003         No disponible
# 2512      AVENIDA MONFORTE DE LEMOS 13.0, MADRID, 28029         No disponible
# 2513  CALLE REGUERA DE TOMATEROS, 39B No disponible,...         No disponible
# 2514             CARRETERA CASTILLA 12.0, MADRID, 28040         No disponible
#
#         LATITUD  LONGITUD
# 0     40.427243 -3.708600
# 1     40.428724 -3.710101
# 2     40.424246 -3.694603
# 3     40.425298 -3.692202
# 4     40.425562 -3.693176
# ...         ...       ...
# 2510  40.390369 -3.657214
# 2511  40.440648 -3.709053
# 2512  40.478914 -3.693541
# 2513  40.372421 -3.657452
# 2514  40.438823 -3.742650
#
# [2515 rows x 6 columns]

# %%
df_concat.to_csv("../data/madrid/df_concat.csv", index=False)

# %%
df_concat = pd.read_csv("../data/madrid/df_concat.csv")

# %%
df_concat.to_json('../data/madrid/df_concat.json', orient='records',force_ascii=False)

# %% [markdown]
# OTRO NUEVO ENFOQUE

# %%
df_csalud = pd.read_csv("../data/madrid/Centros atencion medica/centros_salud_filtrado.csv")
df_iglesias = pd.read_csv("../data/madrid/Iglesias/iglesias_filtradas.csv")
df_monumentos = pd.read_csv("../data/madrid/Monumentos/Monumentos_filtrados.csv")
df_museos = pd.read_csv("../data/madrid/museos/museos filtrados.csv")
df_salas = pd.read_csv("../data/madrid/Salas espectaculos artisticos/salas_espectaculos_filtradas.csv")
df_templo_no_cat = pd.read_csv("../data/madrid/Templos_no_catolicos/Templos_filtrados.csv")
df_fuentes = pd.read_csv("../data/madrid/fuentes/fuentes_nuevo_reduced.csv")
df_parques = pd.read_csv("../data/madrid/Parques y jardines/parques_y_jardines_nuevo_reduced.csv")
df_oficinas = pd.read_csv("../data/madrid/oficinas_turismo/tourist_office_nuevo_reduced.csv")
df_piscinas = pd.read_csv("../data/madrid/Piscinas/piscinas_madrid_nuevo_reduced.csv")

# %%
df_concat_reduced = pd.concat([df_fuentes, df_museos, df_parques, df_oficinas, df_piscinas,df_templo_no_cat,df_salas,df_monumentos,df_iglesias,df_csalud], ignore_index=True)
df_concat_reduced
# Out:
#          TIPO                                             NOMBRE  \
# 0     FUENTES                                        FUE_01_0001
# 1     FUENTES                                        FUE_01_0002
# 2     FUENTES                                        FUE_01_0003
# 3     FUENTES                                        FUE_01_0004
# 4     FUENTES                                        FUE_01_0005
# ...       ...                                                ...
# 1589    Salud                   Hospital Universitario HM Madrid
# 1590    Salud  Hospital Universitario Nuestra Señora del Rosario
# 1591    Salud              Hospital Universitario Santa Cristina
# 1592    Salud                        Hospital Viamed Santa Elena
# 1593    Salud                       Hospital Virgen de La Paloma
#
#                                  DIRECCION                   DESCRIPCION  \
# 0               CENTRO, PLAZA COMENDADORAS            PLAZA COMENDADORAS
# 1             CENTRO, JARDINES CONDE DUQUE          JARDINES CONDE DUQUE
# 2             CENTRO, PLAZA DE LAS SALESAS          PLAZA DE LAS SALESAS
# 3             CENTRO, PLAZA VILLA DE PARIS          PLAZA VILLA DE PARIS
# 4             CENTRO, PLAZA VILLA DE PARIS          PLAZA VILLA DE PARIS
# ...                                    ...                           ...
# 1589  PLAZA CONDE DEL VALLE DE SUCHIL 16.0  HospitalesClinicasSanatorios
# 1590        CALLE PRINCIPE DE VERGARA 53.0  HospitalesClinicasSanatorios
# 1591               CALLE MAESTRO VIVES 3.0  HospitalesClinicasSanatorios
# 1592                      CALLE GRANJA 8.0  HospitalesClinicasSanatorios
# 1593                        CALLE LOMA 1.0  HospitalesClinicasSanatorios
#
#         LATITUD  LONGITUD  Unnamed: 0
# 0     40.427243 -3.708600         NaN
# 1     40.428724 -3.710101         NaN
# 2     40.424246 -3.694603         NaN
# 3     40.425298 -3.692202         NaN
# 4     40.425562 -3.693176         NaN
# ...         ...       ...         ...
# 1589  40.431333 -3.706808       247.0
# 1590  40.432034 -3.679778       251.0
# 1591  40.421831 -3.671056       255.0
# 1592  40.445730 -3.717103       257.0
# 1593  40.445344 -3.715989       258.0
#
# [1594 rows x 7 columns]

# %%
df_concat_reduced["TIPO"].unique()
# Out:
# array(['FUENTES', 'MUSEOS', 'PARQUES_Y_JARDINES', 'OFICINAS_TURISMO',
#        'PISCINAS', 'TEMPLOS', 'SALAS ESPECTACULOS', 'MONUMENTOS', 'SALUD'],
#       dtype=object)

# %%
df_concat_reduced['TIPO'] = df_concat_reduced['TIPO'].str.upper()
