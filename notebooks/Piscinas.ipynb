# %%
import requests
import pandas as pd

# %%
def obtener_piscinas():
    url = "https://datos.madrid.es/egob/catalogo/210227-0-piscinas-publicas.csv"
    
    try:
        response = requests.get(url)
        response.raise_for_status()  # Verifica si la solicitud fue exitosa

        # Si la solicitud es exitosa, retorna el contenido en formato CSV
        return response.content

    except requests.exceptions.RequestException as e:
        print("Error al obtener las piscinas:", e)
        return None

# %%
contenido_csv = obtener_piscinas()

# Verificar si se obtuvo el contenido y guardarlo en un archivo CSV
if contenido_csv:
    with open("../data/madrid/Piscinas/piscinas_madrid.csv", "wb") as archivo_csv:
        archivo_csv.write(contenido_csv)
    print("Se ha guardado el archivo piscinas_madrid.csv")
# Out:
# Se ha guardado el archivo piscinas_madrid.csv

# %%
df = pd.read_csv("../data/madrid/Piscinas/piscinas_madrid.csv", sep=";", encoding="latin-1")

# %%
df.head()
# Out:
#          PK                                             NOMBRE  \
# 0      4707  Centro Deportivo Municipal  María Jesús Rosa (...
# 1  10183549               Centro Deportivo Municipal Alcántara
# 2    114782       Centro Deportivo Municipal Alfredo Goyeneche
# 3      4696                  Centro Deportivo Municipal Aluche
# 4      4678  Centro Deportivo Municipal Ángel Nieto (antigu...
#
#    DESCRIPCION-ENTIDAD                                            HORARIO  \
# 0                  NaN  Horario de uso de las instalaciones deportivas...
# 1                  NaN  Horario de uso de las instalaciones deportivas...
# 2                  NaN  Horario de uso de las instalaciones deportivas...
# 3                  NaN  Horario de uso de las instalaciones deportivas...
# 4                  NaN  Horario de uso de las instalaciones deportivas...
#
#                                         EQUIPAMIENTO  \
# 0  Clases deportivas     Pre-infantiles (0 a 5 añ...
# 1  Clases y escuelas deportivas    Pre-infantiles...
# 2  Clases y escuelas deportivas     Pre infantile...
# 3  Clases y escuelas deportivas       Pre-Infanti...
# 4  Clases y escuelas deportivas    Pre-infantiles...
#
#                                           TRANSPORTE DESCRIPCION  \
# 0  Metro: Barrio del Pilar , Peñagrande.   Bus: 4...         NaN
# 1  Metro: Lista, Manuel Becerra.  Bus: 21, 43, 53...         NaN
# 2  Bus: 160, 161, 658  Renfe:  Aravaca   Biciclet...         NaN
# 3  Metro: Aluche  Bus: 17, 34, 139  Cercanías Ren...         NaN
# 4  Metro: Portazgo.  Bus:   10 , 54 , 57 , 58 , 1...         NaN
#
#   ACCESIBILIDAD                                        CONTENT-URL  \
# 0             1  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1             1  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2             1  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 3             1  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 4             1  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#           NOMBRE-VIA  ...             DISTRITO COORDENADA-X  COORDENADA-Y  \
# 0  MONFORTE DE LEMOS  ...  FUENCARRAL-EL PARDO       439931       4481139
# 1          ALCANTARA  ...            SALAMANCA       442851       4475492
# 2  ARROYO DE POZUELO  ...      MONCLOA-ARAVACA       433581       4478234
# 3     DE LAS AGUILAS  ...               LATINA       434332       4470525
# 4        PAYASO FOFO  ...   PUENTE DE VALLECAS       443998       4471417
#
#      LATITUD  LONGITUD                              TELEFONO  FAX  \
# 0  40.478768 -3.708699  914 800 476 - idmlavaguada@madrid.es  NaN
# 1  40.428103 -3.673732                           917 373 641  NaN
# 2  40.452121 -3.783283                           913 571 228  NaN
# 3  40.382721 -3.773654                           917 062 868  NaN
# 4  40.391462 -3.659864                           914 781 492  NaN
#
#                      EMAIL                                               TIPO  \
# 0   idmlavaguada@madrid.es  /contenido/entidadesYorganismos/CentrosEspacio...
# 1      alcantara@viding.es  /contenido/entidadesYorganismos/CentrosEspacio...
# 2  idmagoyeneche@madrid.es  /contenido/entidadesYorganismos/CentrosEspacio...
# 3      idmaluche@madrid.es  /contenido/entidadesYorganismos/CentrosEspacio...
# 4   idmpvallecas@madrid.es  /contenido/entidadesYorganismos/CentrosEspacio...
#
#    Unnamed: 32
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PK                   59 non-null     int64
#  1   NOMBRE               59 non-null     object
#  2   DESCRIPCION-ENTIDAD  0 non-null      float64
#  3   HORARIO              58 non-null     object
#  4   EQUIPAMIENTO         57 non-null     object
#  5   TRANSPORTE           59 non-null     object
#  6   DESCRIPCION          7 non-null      object
#  7   ACCESIBILIDAD        59 non-null     object
#  8   CONTENT-URL          59 non-null     object
#  9   NOMBRE-VIA           59 non-null     object
#  10  CLASE-VIAL           59 non-null     object
#  11  TIPO-NUM             59 non-null     object
#  12  NUM                  58 non-null     float64
#  13  PLANTA               0 non-null      float64
#  14  PUERTA               0 non-null      float64
#  15  ESCALERAS            0 non-null      float64
#  16  ORIENTACION          1 non-null      object
#  17  LOCALIDAD            59 non-null     object
#  18  PROVINCIA            59 non-null     object
#  19  CODIGO-POSTAL        59 non-null     int64
#  20  COD-BARRIO           57 non-null     float64
#  21  BARRIO               59 non-null     object
#  22  COD-DISTRITO         57 non-null     float64
#  23  DISTRITO             59 non-null     object
#  24  COORDENADA-X         59 non-null     int64
#  25  COORDENADA-Y         59 non-null     int64
#  26  LATITUD              59 non-null     float64
#  27  LONGITUD             59 non-null     float64
#  28  TELEFONO             58 non-null     object
#  29  FAX                  2 non-null      object
#  30  EMAIL                57 non-null     object
#  31  TIPO                 59 non-null     object
#  32  Unnamed: 32          59 non-null     object
# dtypes: float64(9), int64(4), object(20)
# memory usage: 15.3+ KB

# %%
df.describe()
# Out:
#                  PK  DESCRIPCION-ENTIDAD         NUM  PLANTA  PUERTA  \
# count  5.900000e+01                  0.0   58.000000     0.0     0.0
# mean   1.562421e+06                  NaN   32.810345     NaN     NaN
# std    3.224063e+06                  NaN   57.872351     NaN     NaN
# min    4.672000e+03                  NaN    1.000000     NaN     NaN
# 25%    4.689500e+03                  NaN    5.000000     NaN     NaN
# 50%    4.707000e+03                  NaN   13.500000     NaN     NaN
# 75%    1.278940e+05                  NaN   35.250000     NaN     NaN
# max    1.202219e+07                  NaN  376.000000     NaN     NaN
#
#        ESCALERAS  CODIGO-POSTAL  COD-BARRIO  COD-DISTRITO   COORDENADA-X  \
# count        0.0      59.000000   57.000000     57.000000      59.000000
# mean         NaN   28027.525424    3.438596     10.385965  441988.966102
# std          NaN      14.491800    1.927411      5.195308    3791.281750
# min          NaN   28002.000000    1.000000      1.000000  433581.000000
# 25%          NaN   28017.500000    2.000000      7.000000  439578.500000
# 50%          NaN   28029.000000    3.000000     10.000000  441216.000000
# 75%          NaN   28039.500000    5.000000     14.000000  444285.000000
# max          NaN   28054.000000    7.000000     21.000000  450176.000000
#
#        COORDENADA-Y    LATITUD   LONGITUD
# count  5.900000e+01  59.000000  59.000000
# mean   4.474764e+06  40.421316  -3.683938
# std    4.265016e+03   0.038415   0.044624
# min    4.466411e+06  40.346220  -3.783283
# 25%    4.471206e+06  40.389436  -3.712325
# 50%    4.474779e+06  40.421720  -3.692821
# 75%    4.478242e+06  40.452689  -3.656582
# max    4.483276e+06  40.498095  -3.587693

# %%
df = df.drop(["DESCRIPCION-ENTIDAD","DESCRIPCION","PLANTA","PUERTA","ESCALERAS","ORIENTACION","FAX","EMAIL","Unnamed: 32","CONTENT-URL","COD-BARRIO","COD-DISTRITO","TELEFONO","TIPO","LOCALIDAD","PROVINCIA","EQUIPAMIENTO","ACCESIBILIDAD","HORARIO","CODIGO-POSTAL","TIPO-NUM"],axis=1)

# %%
df.head()
# Out:
#          PK                                             NOMBRE  \
# 0      4707  Centro Deportivo Municipal  María Jesús Rosa (...
# 1  10183549               Centro Deportivo Municipal Alcántara
# 2    114782       Centro Deportivo Municipal Alfredo Goyeneche
# 3      4696                  Centro Deportivo Municipal Aluche
# 4      4678  Centro Deportivo Municipal Ángel Nieto (antigu...
#
#                                           TRANSPORTE         NOMBRE-VIA  \
# 0  Metro: Barrio del Pilar , Peñagrande.   Bus: 4...  MONFORTE DE LEMOS
# 1  Metro: Lista, Manuel Becerra.  Bus: 21, 43, 53...          ALCANTARA
# 2  Bus: 160, 161, 658  Renfe:  Aravaca   Biciclet...  ARROYO DE POZUELO
# 3  Metro: Aluche  Bus: 17, 34, 139  Cercanías Ren...     DE LAS AGUILAS
# 4  Metro: Portazgo.  Bus:   10 , 54 , 57 , 58 , 1...        PAYASO FOFO
#
#   CLASE-VIAL   NUM           BARRIO             DISTRITO  COORDENADA-X  \
# 0    AVENIDA  38.0         EL PILAR  FUENCARRAL-EL PARDO        439931
# 1      CALLE  26.0             GOYA            SALAMANCA        442851
# 2      CALLE  99.0          ARAVACA      MONCLOA-ARAVACA        433581
# 3    AVENIDA  14.0      LAS AGUILAS               LATINA        434332
# 4      CALLE   7.0  PALOMERAS BAJAS   PUENTE DE VALLECAS        443998
#
#    COORDENADA-Y    LATITUD  LONGITUD
# 0       4481139  40.478768 -3.708699
# 1       4475492  40.428103 -3.673732
# 2       4478234  40.452121 -3.783283
# 3       4470525  40.382721 -3.773654
# 4       4471417  40.391462 -3.659864

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PK            59 non-null     int64
#  1   NOMBRE        59 non-null     object
#  2   TRANSPORTE    59 non-null     object
#  3   NOMBRE-VIA    59 non-null     object
#  4   CLASE-VIAL    59 non-null     object
#  5   NUM           58 non-null     float64
#  6   BARRIO        59 non-null     object
#  7   DISTRITO      59 non-null     object
#  8   COORDENADA-X  59 non-null     int64
#  9   COORDENADA-Y  59 non-null     int64
#  10  LATITUD       59 non-null     float64
#  11  LONGITUD      59 non-null     float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 5.7+ KB

# %%
df["NUM"] = df["NUM"].fillna("No disponible")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PK            59 non-null     int64
#  1   NOMBRE        59 non-null     object
#  2   TRANSPORTE    59 non-null     object
#  3   NOMBRE-VIA    59 non-null     object
#  4   CLASE-VIAL    59 non-null     object
#  5   NUM           59 non-null     object
#  6   BARRIO        59 non-null     object
#  7   DISTRITO      59 non-null     object
#  8   COORDENADA-X  59 non-null     int64
#  9   COORDENADA-Y  59 non-null     int64
#  10  LATITUD       59 non-null     float64
#  11  LONGITUD      59 non-null     float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 5.7+ KB

# %%
df.describe()
# Out:
#                  PK   COORDENADA-X  COORDENADA-Y    LATITUD   LONGITUD
# count  5.900000e+01      59.000000  5.900000e+01  59.000000  59.000000
# mean   1.562421e+06  441988.966102  4.474764e+06  40.421316  -3.683938
# std    3.224063e+06    3791.281750  4.265016e+03   0.038415   0.044624
# min    4.672000e+03  433581.000000  4.466411e+06  40.346220  -3.783283
# 25%    4.689500e+03  439578.500000  4.471206e+06  40.389436  -3.712325
# 50%    4.707000e+03  441216.000000  4.474779e+06  40.421720  -3.692821
# 75%    1.278940e+05  444285.000000  4.478242e+06  40.452689  -3.656582
# max    1.202219e+07  450176.000000  4.483276e+06  40.498095  -3.587693

# %%
df.head()
# Out:
#          PK                                             NOMBRE  \
# 0      4707  Centro Deportivo Municipal  María Jesús Rosa (...
# 1  10183549               Centro Deportivo Municipal Alcántara
# 2    114782       Centro Deportivo Municipal Alfredo Goyeneche
# 3      4696                  Centro Deportivo Municipal Aluche
# 4      4678  Centro Deportivo Municipal Ángel Nieto (antigu...
#
#                                           TRANSPORTE         NOMBRE-VIA  \
# 0  Metro: Barrio del Pilar , Peñagrande.   Bus: 4...  MONFORTE DE LEMOS
# 1  Metro: Lista, Manuel Becerra.  Bus: 21, 43, 53...          ALCANTARA
# 2  Bus: 160, 161, 658  Renfe:  Aravaca   Biciclet...  ARROYO DE POZUELO
# 3  Metro: Aluche  Bus: 17, 34, 139  Cercanías Ren...     DE LAS AGUILAS
# 4  Metro: Portazgo.  Bus:   10 , 54 , 57 , 58 , 1...        PAYASO FOFO
#
#   CLASE-VIAL   NUM           BARRIO             DISTRITO  COORDENADA-X  \
# 0    AVENIDA  38.0         EL PILAR  FUENCARRAL-EL PARDO        439931
# 1      CALLE  26.0             GOYA            SALAMANCA        442851
# 2      CALLE  99.0          ARAVACA      MONCLOA-ARAVACA        433581
# 3    AVENIDA  14.0      LAS AGUILAS               LATINA        434332
# 4      CALLE   7.0  PALOMERAS BAJAS   PUENTE DE VALLECAS        443998
#
#    COORDENADA-Y    LATITUD  LONGITUD
# 0       4481139  40.478768 -3.708699
# 1       4475492  40.428103 -3.673732
# 2       4478234  40.452121 -3.783283
# 3       4470525  40.382721 -3.773654
# 4       4471417  40.391462 -3.659864

# %%
# Intercambiamos el orden de las columnas 3 y 4 para luego cambiarles el nombre para favorecer la visualización.
df.iloc[:, [3, 4]] = df.iloc[:, [4, 3]].values

# %%
df.rename(columns={"NOMBRE-VIA": "CLASE-VIA", "CLASE-VIAL": "NOMBRE-VIA"}, inplace=True)

# %%
df.head()
# Out:
#          PK                                             NOMBRE  \
# 0      4707  Centro Deportivo Municipal  María Jesús Rosa (...
# 1  10183549               Centro Deportivo Municipal Alcántara
# 2    114782       Centro Deportivo Municipal Alfredo Goyeneche
# 3      4696                  Centro Deportivo Municipal Aluche
# 4      4678  Centro Deportivo Municipal Ángel Nieto (antigu...
#
#                                           TRANSPORTE CLASE-VIA  \
# 0  Metro: Barrio del Pilar , Peñagrande.   Bus: 4...   AVENIDA
# 1  Metro: Lista, Manuel Becerra.  Bus: 21, 43, 53...     CALLE
# 2  Bus: 160, 161, 658  Renfe:  Aravaca   Biciclet...     CALLE
# 3  Metro: Aluche  Bus: 17, 34, 139  Cercanías Ren...   AVENIDA
# 4  Metro: Portazgo.  Bus:   10 , 54 , 57 , 58 , 1...     CALLE
#
#           NOMBRE-VIA   NUM           BARRIO             DISTRITO  \
# 0  MONFORTE DE LEMOS  38.0         EL PILAR  FUENCARRAL-EL PARDO
# 1          ALCANTARA  26.0             GOYA            SALAMANCA
# 2  ARROYO DE POZUELO  99.0          ARAVACA      MONCLOA-ARAVACA
# 3     DE LAS AGUILAS  14.0      LAS AGUILAS               LATINA
# 4        PAYASO FOFO   7.0  PALOMERAS BAJAS   PUENTE DE VALLECAS
#
#    COORDENADA-X  COORDENADA-Y    LATITUD  LONGITUD
# 0        439931       4481139  40.478768 -3.708699
# 1        442851       4475492  40.428103 -3.673732
# 2        433581       4478234  40.452121 -3.783283
# 3        434332       4470525  40.382721 -3.773654
# 4        443998       4471417  40.391462 -3.659864

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PK            59 non-null     int64
#  1   NOMBRE        59 non-null     object
#  2   TRANSPORTE    59 non-null     object
#  3   CLASE-VIA     59 non-null     object
#  4   NOMBRE-VIA    59 non-null     object
#  5   NUM           59 non-null     object
#  6   BARRIO        59 non-null     object
#  7   DISTRITO      59 non-null     object
#  8   COORDENADA-X  59 non-null     int64
#  9   COORDENADA-Y  59 non-null     int64
#  10  LATITUD       59 non-null     float64
#  11  LONGITUD      59 non-null     float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 5.7+ KB

# %%
nombre_archivo = "../Json/piscinas.json"

# %%
df.to_json(nombre_archivo, orient='records')
